# %%
''' 
@ohumkar 
Code Issues 0 Pull requests 0 Actions Wiki Security 0 Pulse Community
Advanced-Deep-Learning-with-Keras/chapter4-gan/dcgan-mnist-4.2.1.py /
@roatienza roatienza code migration to tf.keras
e50000e on Dec 14, 2019
311 lines (266 sloc)  10.8 KB
  
Code navigation is available!
Navigate your code with ease. Click on function and method calls to jump to their definitions or references in the same repository. Learn more
'''

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Activation, Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

import numpy as np
import math
import matplotlib.pyplot as plt
import os
import argparse

# %%
def build_generator(inputs, image_size):
    """Build a Generator Model
    Stack of BN-ReLU-Conv2DTranpose to generate fake images
    Output activation is sigmoid instead of tanh in [1].
    Sigmoid converges easily.
    Arguments:
        inputs (Layer): Input layer of the generator 
            the z-vector)
        image_size (tensor): Target size of one side
            (assuming square image)
    Returns:
        generator (Model): Generator Model
    """

    image_resize = image_size // 4
    # network parameters 
    kernel_size = 5
    layer_filters = [128, 64, 32, 1]

    x = Dense(image_resize * image_resize * layer_filters[0])(inputs)
    x = Reshape((image_resize, image_resize, layer_filters[0]))(x)

    for filters in layer_filters:
        # first two convolution layers use strides = 2
        # the last two use strides = 1
        if filters > layer_filters[-2]:
            strides = 2
        else:
            strides = 1
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2DTranspose(filters=filters,
                            kernel_size=kernel_size,
                            strides=strides,
                            padding='same')(x)

    x = Activation('sigmoid')(x)
    generator = Model(inputs, x, name='generator')
    return generator


def build_discriminator(inputs):
    """Build a Discriminator Model
    Stack of LeakyReLU-Conv2D to discriminate real from fake.
    The network does not converge with BN so it is not used here
    unlike in [1] or original paper.
    Arguments:
        inputs (Layer): Input layer of the discriminator (the image)
    Returns:
        discriminator (Model): Discriminator Model
    """
    kernel_size = 5
    layer_filters = [32, 64, 128, 256]

    x = inputs
    for filters in layer_filters:
        # first 3 convolution layers use strides = 2
        # last one uses strides = 1
        if filters == layer_filters[-1]:
            strides = 1
        else:
            strides = 2
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv2D(filters=filters,
                   kernel_size=kernel_size,
                   strides=strides,
                   padding='same')(x)

    x = Flatten()(x)
    x = Dense(1)(x)
    x = Activation('sigmoid')(x)
    discriminator = Model(inputs, x, name='discriminator')
    return discriminator

# %%
def train(models, x_train, params):
    """Train the Discriminator and Adversarial Networks
    Alternately train Discriminator and Adversarial networks by batch.
    Discriminator is trained first with properly real and fake images.
    Adversarial is trained next with fake images pretending to be real
    Generate sample images per save_interval.
    Arguments:
        models (list): Generator, Discriminator, Adversarial models
        x_train (tensor): Train images
        params (list) : Networks parameters
    """
    # the GAN component models
    generator, discriminator, adversarial = models
    # network parameters
    batch_size, latent_size,n_critic, clip_value, train_steps, model_name = params
    # the generator image is saved every 500 steps
    save_interval = 50
    # noise vector to see how the generator output evolves during training
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, latent_size])
    # number of elements in train dataset
    train_size = x_train.shape[0]
    real_labels = np.ones((batch_size, 1))
    for i in range(train_steps):
      loss = 0
      acc = 0
      for _ in range(n_critic) :
        # train the discriminator for 1 batch
        # 1 batch of real (label=1.0) and fake images (label=0.0)
        # randomly pick real images from dataset
        rand_indexes = np.random.randint(0, train_size, size=batch_size)
        real_images = x_train[rand_indexes]
        # generate fake images from noise using generator 
        # generate noise using uniform distribution
        noise = np.random.uniform(-1.0,
                                  1.0,
                                  size=[batch_size, latent_size])
        # generate fake images
        fake_images = generator.predict(noise)

        #real data label = 1, fake data label = -1

        #instead of training real and fake together ... train separately --> tweak for gradient flow
        real_loss, real_acc = discriminator.train_on_batch(real_images, real_labels)
        fake_loss, fake_acc = discriminator.train_on_batch(fake_images, -real_labels)

        #get combined loss
        acc += 0.5*(real_acc + fake_acc)
        loss += 0.5*(real_loss + fake_loss)

        #clip weights to satisfy Lipschitz constrain
        for layer in discriminator.layers :
          weights = layer.get_weights()
          weights = [np.clip(weight, -clip_value, clip_value) for weight in weights]
          layer.set_weights(weights)
      #average loss and acc per n_critic
      loss /= n_critic
      acc /= n_critic
      log = "%d: [discriminator loss: %f, acc: %f]" % (i, loss, acc)
        

      # train the adversarial network for 1 batch
      # 1 batch of fake images with label=1.0
      # since the discriminator weights 
      # are frozen in adversarial network
      # only the generator is trained
      # generate noise using uniform distribution
      noise = np.random.uniform(-1.0,
                                1.0, 
                                size=[batch_size, latent_size])
      # label fake images as real or 1.0
      y = np.ones([batch_size, 1])
      # train the adversarial network 
      # note that unlike in discriminator training, 
      # we do not save the fake images in a variable
      # the fake images go to the discriminator input of the adversarial
      # for classification
      # log the loss and accuracy
      loss, acc = adversarial.train_on_batch(noise, y)
      log = "%s [adversarial loss: %f, acc: %f]" % (log, loss, acc)
      print(log)
      if (i + 1) % save_interval == 0:
          # plot generator images on a periodic basis
          plot_images(generator,
                      noise_input=noise_input,
                      show=False,
                      step=(i + 1),
                      model_name=model_name)
   
    # save the model after training the generator
    # the trained generator can be reloaded for 
    # future MNIST digit generation
    generator.save(model_name + ".h5")

# %%
def plot_images(generator,
                noise_input,
                show=False,
                step=0,
                model_name="gan"):
    """Generate fake images and plot them
    For visualization purposes, generate fake images
    then plot them in a square grid
    Arguments:
        generator (Model): The Generator Model for 
            fake images generation
        noise_input (ndarray): Array of z-vectors
        show (bool): Whether to show plot or not
        step (int): Appended to filename of the save images
        model_name (string): Model name
    """
    os.makedirs(model_name, exist_ok=True)
    filename = os.path.join(model_name, "%05d.png" % step)
    images = generator.predict(noise_input)
    plt.figure(figsize=(2.2, 2.2))
    num_images = images.shape[0]
    image_size = images.shape[1]
    rows = int(math.sqrt(noise_input.shape[0]))
    for i in range(num_images):
        plt.subplot(rows, rows, i + 1)
        image = np.reshape(images[i], [image_size, image_size])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.savefig(filename)
    if show:
        plt.show()
    else:
        plt.close('all')

# %%
def wasserstein_loss(y_label, y_pred):
    return -K.mean(y_label * y_pred)

# %%
def build_and_train_models():
    # load MNIST dataset
    (x_train, _), (_, _) = mnist.load_data()

    # reshape data for CNN as (28, 28, 1) and normalize
    image_size = x_train.shape[1]
    x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
    x_train = x_train.astype('float32') / 255

    model_name = "wgan_mnist"
    # network parameters
    # the latent or z vector is 100-dim
    latent_size = 100
    batch_size = 64
    n_critic = 5
    clip_value = 0.01
    train_steps = 200
    lr = 5e-5
    input_shape = (image_size, image_size, 1)

    # build discriminator model
    inputs = Input(shape=input_shape, name='discriminator_input')
    discriminator = build_discriminator(inputs)
    # [1] or original paper uses Adam, 
    # but discriminator converges easily with RMSprop
    optimizer = RMSprop(lr=lr)
    discriminator.compile(loss=wasserstein_loss,
                          optimizer=optimizer,
                          metrics=['accuracy'])
    #discriminator.summary()
    plot_model(discriminator, to_file='discriminator-mnist.png', show_shapes=True)

    # build generator model
    input_shape = (latent_size, )
    inputs = Input(shape=input_shape, name='z_input')
    generator = build_generator(inputs, image_size)
    #generator.summary()
    plot_model(generator, to_file='generator-mnist.png', show_shapes=True)

    # build adversarial model
    optimizer = RMSprop(lr=lr * 0.5)
    # freeze the weights of discriminator during adversarial training
    discriminator.trainable = False
    # adversarial = generator + discriminator
    adversarial = Model(inputs, 
                        discriminator(generator(inputs)),
                        name=model_name)
    adversarial.compile(loss='binary_crossentropy',
                        optimizer=optimizer,
                        metrics=['accuracy'])
    #adversarial.summary()
    plot_model(adversarial, to_file='adversarial-mnist.png', show_shapes=True)

    # train discriminator and adversarial networks
    models = (generator, discriminator, adversarial)
    params = (batch_size, latent_size,n_critic, clip_value, train_steps, model_name)
    train(models, x_train, params)

# %%
def test_generator(generator):
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, 100])
    plot_images(generator,
                noise_input=noise_input,
                show=True,
                model_name="test_outputs")

# %%
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     help_ = "Load generator h5 model with trained weights"
#     parser.add_argument("-g", "--generator", help=help_)
#     args = parser.parse_args()
#     if args.generator:
#         generator = load_model(args.generator)
#         test_generator(generator)
#     else:
#         build_and_train_models()

# %%
build_and_train_models()
# Out:
# 0: [discriminator loss: 0.002833, acc: 0.468750] [adversarial loss: 0.693102, acc: 1.000000]
# 1: [discriminator loss: -0.000031, acc: 0.500000] [adversarial loss: 0.693258, acc: 0.000000]
# 2: [discriminator loss: -0.000082, acc: 0.500000] [adversarial loss: 0.693536, acc: 0.000000]
# 3: [discriminator loss: -0.000180, acc: 0.500000] [adversarial loss: 0.694082, acc: 0.000000]
# 4: [discriminator loss: -0.000374, acc: 0.500000] [adversarial loss: 0.695220, acc: 0.000000]
# 5: [discriminator loss: -0.000837, acc: 0.493750] [adversarial loss: 0.697566, acc: 0.000000]
# 6: [discriminator loss: -0.001867, acc: 0.492188] [adversarial loss: 0.702073, acc: 0.000000]
# 7: [discriminator loss: -0.003974, acc: 0.481250] [adversarial loss: 0.709554, acc: 0.000000]
# 8: [discriminator loss: -0.007845, acc: 0.492188] [adversarial loss: 0.720967, acc: 0.000000]
# 9: [discriminator loss: -0.014207, acc: 0.485938] [adversarial loss: 0.735508, acc: 0.000000]
# 10: [discriminator loss: -0.024017, acc: 0.495312] [adversarial loss: 0.751927, acc: 0.000000]
# 11: [discriminator loss: -0.037734, acc: 0.493750] [adversarial loss: 0.764149, acc: 0.000000]
# 12: [discriminator loss: -0.057951, acc: 0.495312] [adversarial loss: 0.774403, acc: 0.000000]
# 13: [discriminator loss: -0.083192, acc: 0.496875] [adversarial loss: 0.778212, acc: 0.000000]
# 14: [discriminator loss: -0.114117, acc: 0.493750] [adversarial loss: 0.771680, acc: 0.000000]
# 15: [discriminator loss: -0.154387, acc: 0.495312] [adversarial loss: 0.743314, acc: 0.000000]
# 16: [discriminator loss: -0.200060, acc: 0.495312] [adversarial loss: 0.708329, acc: 0.265625]
# 17: [discriminator loss: -0.246293, acc: 0.498437] [adversarial loss: 0.637558, acc: 0.953125]
# 18: [discriminator loss: -0.292723, acc: 0.500000] [adversarial loss: 0.552137, acc: 1.000000]
# 19: [discriminator loss: -0.342211, acc: 0.498437] [adversarial loss: 0.462422, acc: 1.000000]
# 20: [discriminator loss: -0.383084, acc: 0.500000] [adversarial loss: 0.368458, acc: 1.000000]
# 21: [discriminator loss: -0.416410, acc: 0.500000] [adversarial loss: 0.280812, acc: 1.000000]
# 22: [discriminator loss: -0.439046, acc: 0.498437] [adversarial loss: 0.197319, acc: 1.000000]
# 23: [discriminator loss: -0.459387, acc: 0.498437] [adversarial loss: 0.141632, acc: 1.000000]
# 24: [discriminator loss: -0.474261, acc: 0.500000] [adversarial loss: 0.102942, acc: 1.000000]
# 25: [discriminator loss: -0.481895, acc: 0.500000] [adversarial loss: 0.068559, acc: 1.000000]
# 26: [discriminator loss: -0.488023, acc: 0.500000] [adversarial loss: 0.044974, acc: 1.000000]
# 27: [discriminator loss: -0.492426, acc: 0.500000] [adversarial loss: 0.029501, acc: 1.000000]
# 28: [discriminator loss: -0.495079, acc: 0.500000] [adversarial loss: 0.019653, acc: 1.000000]
# 29: [discriminator loss: -0.496990, acc: 0.500000] [adversarial loss: 0.013771, acc: 1.000000]
# 30: [discriminator loss: -0.497989, acc: 0.500000] [adversarial loss: 0.008458, acc: 1.000000]
# 31: [discriminator loss: -0.498422, acc: 0.500000] [adversarial loss: 0.004600, acc: 1.000000]
# 32: [discriminator loss: -0.497176, acc: 0.498437] [adversarial loss: 0.003507, acc: 1.000000]
# 33: [discriminator loss: -0.499601, acc: 0.500000] [adversarial loss: 0.002849, acc: 1.000000]
# 34: [discriminator loss: -0.499617, acc: 0.500000] [adversarial loss: 0.001962, acc: 1.000000]
# 35: [discriminator loss: -0.499662, acc: 0.500000] [adversarial loss: 0.001329, acc: 1.000000]
# 36: [discriminator loss: -0.499821, acc: 0.500000] [adversarial loss: 0.001165, acc: 1.000000]
# 37: [discriminator loss: -0.499869, acc: 0.500000] [adversarial loss: 0.000765, acc: 1.000000]
# 38: [discriminator loss: -0.497336, acc: 0.500000] [adversarial loss: 0.000583, acc: 1.000000]
# 39: [discriminator loss: -0.499887, acc: 0.500000] [adversarial loss: 0.000498, acc: 1.000000]
# 40: [discriminator loss: -0.499921, acc: 0.500000] [adversarial loss: 0.000466, acc: 1.000000]
# 41: [discriminator loss: -0.499928, acc: 0.500000] [adversarial loss: 0.000405, acc: 1.000000]
# 42: [discriminator loss: -0.499952, acc: 0.500000] [adversarial loss: 0.000412, acc: 1.000000]
# 43: [discriminator loss: -0.498144, acc: 0.498437] [adversarial loss: 0.000313, acc: 1.000000]
# 44: [discriminator loss: -0.499968, acc: 0.500000] [adversarial loss: 0.000322, acc: 1.000000]
# 45: [discriminator loss: -0.499962, acc: 0.500000] [adversarial loss: 0.000306, acc: 1.000000]
# 46: [discriminator loss: -0.499956, acc: 0.500000] [adversarial loss: 0.000263, acc: 1.000000]
# 47: [discriminator loss: -0.499952, acc: 0.500000] [adversarial loss: 0.000207, acc: 1.000000]
# 48: [discriminator loss: -0.499979, acc: 0.500000] [adversarial loss: 0.000219, acc: 1.000000]
# 49: [discriminator loss: -0.499970, acc: 0.500000] [adversarial loss: 0.000182, acc: 1.000000]
# 50: [discriminator loss: -0.499986, acc: 0.500000] [adversarial loss: 0.000191, acc: 1.000000]
# 51: [discriminator loss: -0.499987, acc: 0.500000] [adversarial loss: 0.000165, acc: 1.000000]
# 52: [discriminator loss: -0.499993, acc: 0.500000] [adversarial loss: 0.000173, acc: 1.000000]
# 53: [discriminator loss: -0.499993, acc: 0.500000] [adversarial loss: 0.000108, acc: 1.000000]
# 54: [discriminator loss: -0.499267, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 55: [discriminator loss: -0.499962, acc: 0.500000] [adversarial loss: 0.000009, acc: 1.000000]
# 56: [discriminator loss: -0.499983, acc: 0.500000] [adversarial loss: 0.000012, acc: 1.000000]
# 57: [discriminator loss: -0.499625, acc: 0.500000] [adversarial loss: 0.000020, acc: 1.000000]
# 58: [discriminator loss: -0.499984, acc: 0.500000] [adversarial loss: 0.000017, acc: 1.000000]
# 59: [discriminator loss: -0.499996, acc: 0.500000] [adversarial loss: 0.000019, acc: 1.000000]
# 60: [discriminator loss: -0.499996, acc: 0.500000] [adversarial loss: 0.000021, acc: 1.000000]
# 61: [discriminator loss: -0.499997, acc: 0.500000] [adversarial loss: 0.000024, acc: 1.000000]
# 62: [discriminator loss: -0.499987, acc: 0.500000] [adversarial loss: 0.000013, acc: 1.000000]
# 63: [discriminator loss: -0.499995, acc: 0.500000] [adversarial loss: 0.000012, acc: 1.000000]
# 64: [discriminator loss: -0.499998, acc: 0.500000] [adversarial loss: 0.000018, acc: 1.000000]
# 65: [discriminator loss: -0.499912, acc: 0.500000] [adversarial loss: 0.000026, acc: 1.000000]
# 66: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000025, acc: 1.000000]
# 67: [discriminator loss: -0.499987, acc: 0.500000] [adversarial loss: 0.000007, acc: 1.000000]
# 68: [discriminator loss: -0.499994, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 69: [discriminator loss: -0.499486, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 70: [discriminator loss: -0.499997, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 71: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 72: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 73: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 74: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 75: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 76: [discriminator loss: -0.499981, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 77: [discriminator loss: -0.499998, acc: 0.500000] [adversarial loss: 0.000003, acc: 1.000000]
# 78: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 79: [discriminator loss: -0.499989, acc: 0.500000] [adversarial loss: 0.000008, acc: 1.000000]
# 80: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000008, acc: 1.000000]
# 81: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000007, acc: 1.000000]
# 82: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 83: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 84: [discriminator loss: -0.499908, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 85: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 86: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 87: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 88: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000005, acc: 1.000000]
# 89: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 90: [discriminator loss: -0.499823, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 91: [discriminator loss: -0.498578, acc: 0.498437] [adversarial loss: 0.000000, acc: 1.000000]
# 92: [discriminator loss: -0.499995, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 93: [discriminator loss: -0.499997, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 94: [discriminator loss: -0.499998, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 95: [discriminator loss: -0.499997, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 96: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 97: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 98: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 99: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 100: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 101: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000003, acc: 1.000000]
# 102: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 103: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000003, acc: 1.000000]
# 104: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000005, acc: 1.000000]
# 105: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 106: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000005, acc: 1.000000]
# 107: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000011, acc: 1.000000]
# 108: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000014, acc: 1.000000]
# 109: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000026, acc: 1.000000]
# 110: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 111: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000005, acc: 1.000000]
# 112: [discriminator loss: -0.499992, acc: 0.500000] [adversarial loss: 0.000008, acc: 1.000000]
# 113: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000007, acc: 1.000000]
# 114: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 115: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 116: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 117: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000007, acc: 1.000000]
# 118: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000003, acc: 1.000000]
# 119: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000003, acc: 1.000000]
# 120: [discriminator loss: -0.499990, acc: 0.500000] [adversarial loss: 0.000007, acc: 1.000000]
# 121: [discriminator loss: -0.499905, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 122: [discriminator loss: -0.499998, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 123: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 124: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 125: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 126: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 127: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 128: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 129: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 130: [discriminator loss: -0.499827, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 131: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 132: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 133: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 134: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 135: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 136: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 137: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 138: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 139: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 140: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 141: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 142: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 143: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000003, acc: 1.000000]
# 144: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 145: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 146: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000021, acc: 1.000000]
# 147: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000017, acc: 1.000000]
# 148: [discriminator loss: -0.499987, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 149: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 150: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 151: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 152: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 153: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 154: [discriminator loss: -0.499986, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 155: [discriminator loss: -0.499952, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 156: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 157: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 158: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 159: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 160: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000000, acc: 1.000000]
# 161: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 162: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 163: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 164: [discriminator loss: -0.499905, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 165: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 166: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 167: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 168: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 169: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 170: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 171: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 172: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 173: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000003, acc: 1.000000]
# 174: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000003, acc: 1.000000]
# 175: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 176: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
# 177: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 178: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000008, acc: 1.000000]
# 179: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000011, acc: 1.000000]
# 180: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000037, acc: 1.000000]
# 181: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000022, acc: 1.000000]
# 182: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 183: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 184: [discriminator loss: -0.499837, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 185: [discriminator loss: -0.499999, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 186: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 187: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 188: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 189: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000001, acc: 1.000000]
# 190: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 191: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 192: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000002, acc: 1.000000]
# 193: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000004, acc: 1.000000]
# 194: [discriminator loss: -0.499995, acc: 0.500000] [adversarial loss: 0.000033, acc: 1.000000]
# 195: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000021, acc: 1.000000]
# 196: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000016, acc: 1.000000]
# 197: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000016, acc: 1.000000]
# 198: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000015, acc: 1.000000]
# 199: [discriminator loss: -0.500000, acc: 0.500000] [adversarial loss: 0.000006, acc: 1.000000]
